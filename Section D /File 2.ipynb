# %% [markdown]
# Section D: Q1. Which department appears strongest in the dataset and why?
#
#
# ---
# Ans:
# 1. The Computer department appears to be the strongest in the dataset because the top performer is from Computer department that is Gauri who scored 92.97.
# 2. The Average Readiness score of Computer department is the most as compared to all other departments.

# %% [markdown]
# Q2. Which students need immediate academic support and what signals show that?
#
#
# ---
# Ans:
# 1. The Two students from IT department Divya and Harshada needs academic support.
# 2. The reason behind this is as their readiness score appear to be the lowest in the dataset.

# %% [markdown]
# Q3. Which students need immediate academic support and what signals show that?
#
#
# ---
# Ans:
# 1. The Number of comparisons is appeared to be very less in a small dataset.
# 2. Rare edge cases may not occur in the small sample of data.
# 3. The models may memorize because of less data rather than learning the pattern.

# %% [markdown]
# Q4. What extra columns would make the analysis more useful for the internship team?
#
#
# ---
# Ans:
# 1. The extra column of Technical skill will be useful to show the Technical capability of the student.
# 2. Certificates column might also be useful to show the students achivement in extra curricular activies
